# %% [markdown]
# <a href="https://colab.research.google.com/github/akshay-vadhan/data-science-journey/blob/main/python_basic_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Data Science Journey")
# Out:
# Hello Data Science Journey
